# %%
valor = int(input("Entre com um número para saber a tabuada:"))
ind = 0
print('*'*10)
print('Tabuada de {}'.format(valor))
print('*'*10)

while ind <= 10:
    print('{} + {} = {}'.format(valor,ind,(valor+ind)))
    ind= ind+1
# Out:
# Entre com um número para saber a tabuada:3
# **********
# Tabuada de 3
# **********
# 3 + 0 = 3
# 3 + 1 = 4
# 3 + 2 = 5
# 3 + 3 = 6
# 3 + 4 = 7
# 3 + 5 = 8
# 3 + 6 = 9
# 3 + 7 = 10
# 3 + 8 = 11
# 3 + 9 = 12
# 3 + 10 = 13
