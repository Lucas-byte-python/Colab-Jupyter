# %%
#Questão 03
questao = "Questão 03"
print(questao)

n1 = int(input("Digite um número:"))
n2 = int(input("Digite outro número:"))
print("O resultado da soma é",n1+n2)
# Out:
# Questão 03
# Digite um número:5
# Digite outro número:5
# O resultado da soma é 10

# %%
#Questão 04
questao = "Questão 04"
print(questao)

alguma_coisa = input('Digite algo: ')

print('O tipo primitivo  é: {} '.format(type(alguma_coisa)))


print('Só tem espaço? {}'.format(alguma_coisa.isspace()))
print(' É um número? {}'.format(alguma_coisa.isnumeric()))
print('É alfabético? {}'.format(alguma_coisa.isalpha()))
print('É alfanumérico? {}'.format(alguma_coisa.isalnum()))
print('Está em maiúsculas? {}'.format(alguma_coisa.isupper()))
print('Está em minúsculas? {}'.format(alguma_coisa.islower()))
print('Está capitalizado? {}'.format(alguma_coisa.istitle()))
print('A string está vazia ?',alguma_coisa.isprintable())
# Out:
# Questão 04
# Digite algo: 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-a697f564d8cc> in <module>
#       5 alguma_coisa = input('Digite algo: ')
#       6
# ----> 7 print('O tipo primitivo  é: {} '.format(type(alguma_coisa)))
#       8
#       9
#
# TypeError: 'str' object is not callable

# %%
#Questão 05
questao = "Questão 05"
print(questao)

n1 = int(input("Digite qualquer número inteiro:"))
anterior = (n1-1)
sucessor = (n1+1)
print("Anterior:",anterior)
print("Meio Termo:",n1)
print("Sucessor:",sucessor)
# Out:
# Questão 05
# Digite qualquer número inteiro:10
# Anterior: 9
# Meio Termo: 10
# Sucessor: 11

# %%
#Questão 06 
questao = "Questão 06"
print(questao)

n1 = int(input("Digite qualquer número inteiro:"))
dobro = n1*2
triplo = n1*3
raiz = n1**(1/2)
print("Dobro:",dobro)
print("Triplo:",triplo)
print("Raiz:",raiz)
# Out:
# Questão 06
# Digite qualquer número inteiro:100
# Dobro: 200
# Triplo: 300
# Raiz: 10.0

# %%
#Questão 07
questao = "Questão 07"
print(questao)

nota1 = float(input("Digite a nota parcial:"))
nota2 = float(input("Digite a nota bimestral:"))
media = (nota1+nota2) / 2
print(media)
if media < 6:
  print("Reprovado, Boa tentativa!")
else:
  print("Aprovado, Parabéns!")
# Out:
# Questão 07
# Digite a nota parcial:10
# Digite a nota bimestral:5
# 7.5
# Aprovado, Parabéns!

# %%
#Quetão 08
questao = "Questão 08"
print(questao)

metros = float(input('Digite um valor(metros):'))
centimetros = metros * 100
milimetros = metros * 1000
print('Esse é o valor em centimetros:',centimetros)
print('Esse é o valor em milimetros:',milimetros)
# Out:
# Questão 08
# Digite um valor(metros):500
# Esse é o valor em centimetros: 50000.0
# Esse é o valor em milimetros: 500000.0

# %%
#Questão 9
questao = "Questão 09"
print(questao)

numero = int(input('Digite o número que desejar:'))
print(numero, 'x 0  = ',numero * 0)
print(numero, 'x 1  = ',numero * 1)
print(numero, 'x 2  = ',numero * 2)
print(numero, 'x 3  = ',numero * 3)
print(numero, 'x 4  = ',numero * 4)
print(numero, 'x 5  = ',numero * 5)
print(numero, 'x 6  = ',numero * 6)
print(numero, 'x 7  = ',numero * 7)
print(numero, 'x 8  = ',numero * 8)
print(numero, 'x 9  = ',numero * 9)
print(numero, 'x 10 = ',numero * 10)
# Out:
# Questão 09
# Digite o número que desejar:12
# 12 x 0  =  0
# 12 x 1  =  12
# 12 x 2  =  24
# 12 x 3  =  36
# 12 x 4  =  48
# 12 x 5  =  60
# 12 x 6  =  72
# 12 x 7  =  84
# 12 x 8  =  96
# 12 x 9  =  108
# 12 x 10 =  120

# %%
#Questão 10
questao = "Questão 10"
print(questao)

dinheiro = float(input('Quanto dinheiro você tem?' ))
dolar = dinheiro / 3.37
print('Com {} reais você consegue comprar {} dolares.'.format(dinheiro,dolar))
# Out:
# Questão 10
# Quanto dinheiro você tem?0
# Com 0.0 reais você consegue comprar 0.0 dolares.

# %%
#Questão 11
questao = "Questão 11"
print(questao)

altura = float(input('Digite a alturada parede em metros: '))
largura = float(input('Digite a largura da parede em metros: '))
area = altura * largura
tinta = area / 2
print('Para pintar uma área de {} é necessario {} litros de tinta'.format(area,tinta))
# Out:
# Questão 11
# Digite a alturada parede em metros: 50
# Digite a largura da parede em metros: 50
# Para pintar uma área de 2500.0 é necessario 1250.0 litros de tinta

# %%
#Questão 12
questao = "Questão 12"
print(questao)

produto = float(input("Digite o valor do produto:"))
desconto = produto * 0.05
valorfinal = produto - desconto
print("Valor sem desconto é de(cartão):",produto)
print("Valor com o desconto de 5% é de(a vista):",valorfinal)
# Out:
# Questão 12
# Digite o valor do produto:40
# Valor sem desconto é de(cartão): 40.0
# Valor com o desconto de 5% é de(a vista): 38.0

# %%
#Questão 13
questao = "Questão 13"
print(questao)

salarioAntigo = float(input("Digite seu salário:"))
acrescimo = salarioAntigo * 0.15
salarionovo = salarioAntigo + acrescimo
print("Seu salário era dê:",salarioAntigo)
print("Seu salário passará a ser dê:",salarionovo)
# Out:
# Questão 13
# Digite seu salário:60
# Seu salário era dê: 60.0
# Seu salário passará a ser dê: 69.0

# %%
#Questão 14
questao = "Questão 14"
print(questao)

celso = float(input("Digite uma temperatura:"))
fahrenheit = celso * 1.8 + 32
print(fahrenheit)

# %%
#Questão 15
questao = "Questão 15"
print(questao)

km = int(input("Digite o quilômetro andado:"))
dias = int(input("Quantos dias ele foi alugado:"))

precokm = km * 0.15
precodias = dias * 60

valor = precokm + precodias
print("Valor a Pagar:",valor)

# %%
#Questão 16
questao = "Questão 16"
print(questao)

num = float(input("Digite o número que quiser:"))

inteiro = num // 1
print(inteiro)

# %%
#Questão 17
questao = "Questão 17"
print(questao)

cateto = int(input("Digite o Cateto Oposto:"))
adjacente = int(input("Digite o Cateto Adjacente:"))

soma_dos_catetos = (cateto * cateto) + (adjacente * adjacente)

hipotenusa = soma_dos_catetos ** (1/2)
print(hipotenusa)

# %%
#Questão 18
questao = "Questão 18"
print(questao)

cateto_oposto = int(input("Digite Cateto Oposto:"))
cateto_adjacente = int(input("Digite Cateto Adjacente:"))
hipotenusa = int(input("Digite a Hipotenusa:"))
angulo = int(input("Digite o Ângulo que deseja:"))

seno = (hipotenusa * angulo) / cateto_oposto
cosseno = (hipotenusa * angulo) / cateto_adjacente
tangente = (cateto_adjacente * angulo) / cateto_oposto

print(seno)
print(cosseno)
print(tangente)

# %%
#Questão 19
questao = "Questão 19"
print(questao)

import random
nome1 = str(input("Digite o 1° nome:"))
nome2 = str(input("Digite o 2° nome:"))
nome3 = str(input("Digite o 3° nome:"))
nome4 = str(input("Digite o 4° nome:"))

sorteio= [nome1, nome2, nome3, nome4]

escolhido = random.choice(sorteio)
print(escolhido)

# %%
#Questão 20
questao = "Questão 20"
print(questao)

import random
trabalho1 = str(input("Digite o nome do grupo:"))
trabalho2 = str(input("Digite o nome do outro grupo:"))
trabalho3 = str(input("Digite o nome do 3° grupo:"))
trabalho4 = str(input("Digite o nome do 4° grupo:"))

sorteio_das_equipes = [trabalho1, trabalho2, trabalho3, trabalho4]
random.shuffle(sorteio_das_equipes)

print(sorteio_das_equipes)
# Out:
# Questão 20

# %%
questao = "Questão 22"
print(questão)

nome = str(input("Digite o seu nome completo:"))
tamanho = nome.split()
print("Nome com letras maiusculas: {}".format(nome.upper()))
print("Nome com letras minusculas: {}".format(nome.lower()))
print(f"O seu nome tem ao todo {len(nome.strip())} letras")
print(f"O seu primeiro nome tem {len(tamanho[0])} letras")
