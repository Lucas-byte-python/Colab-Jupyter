# %%
# Ex. 1:
b = 'Sem ar'
numbers = [1, 2, 3, 4, 5, 'a',b]
for number in numbers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5
# a
# Sem ar

# %%
# Ex. 2:
legumes = 'batata','macacheira','beterraba'
frutas = ['Abacaxi', 'Morango', 'Uva',legumes]
for fruta in frutas:
    print(fruta)
# Out:
# Abacaxi
# Morango
# Uva
# ('batata', 'macacheira', 'beterraba')

# %%
# Ex. 3:
sentenca = "Vamos estudar Python"
for letra in sentenca:
    print(letra)
# Out:
# V
# a
# m
# o
# s
#
# e
# s
# t
# u
# d
# a
# r
#
# P
# y
# t
# h
# o
# n

# %%
# Ex. 4:
pessoas = [({'nome': 'João', 'cidade': 'Belo Horizonte'}),
           ({'nome': 'Maria', 'cidade': 'São Paulo'}),
           ({'nome': 'Pedro', 'cidade': 'Curitiba'})]
contador = 0
for pessoa in pessoas:
    contador += 1
    print(contador)
    if (pessoa['nome'] == 'Maria')
            and (pessoa['cidade']=='São Paulo'):
      print(pessoa['nome'], "mora em", pessoa['cidade'])
            break
# Out:
#   File "<tokenize>", line 11
#     print(pessoa['nome'], "mora em", pessoa['cidade'])
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Ex. 6:
for numero in range(10):
     if numero % 2 == 0:
        print("O número", numero, "é par")
# Out:
# O número 0 é par
# O número 2 é par
# O número 4 é par
# O número 6 é par
# O número 8 é par

# %%
# Ex. 7:
for numero in range(10):
     if numero % 2 != 0:
        print("O número", numero, "é impar")
# Out:
# O número 1 é impar
# O número 3 é impar
# O número 5 é impar
# O número 7 é impar
# O número 9 é impar

# %%
# Ex. 8:
for numero_coluna1 in range(2, 5):
    print("Tabuada do ", numero_coluna1)
    for numero_coluna2 in range(11):
        print(numero_coluna1, "x", numero_coluna2, " = ",
              numero_coluna1 * numero_coluna2)
# Out:
# Tabuada do  2
# 2 x 0  =  0
# 2 x 1  =  2
# 2 x 2  =  4
# 2 x 3  =  6
# 2 x 4  =  8
# 2 x 5  =  10
# 2 x 6  =  12
# 2 x 7  =  14
# 2 x 8  =  16
# 2 x 9  =  18
# 2 x 10  =  20
# Tabuada do  3
# 3 x 0  =  0
# 3 x 1  =  3
# 3 x 2  =  6
# 3 x 3  =  9
# 3 x 4  =  12
# 3 x 5  =  15
# 3 x 6  =  18
# 3 x 7  =  21
# 3 x 8  =  24
# 3 x 9  =  27
# 3 x 10  =  30
# Tabuada do  4
# 4 x 0  =  0
# 4 x 1  =  4
# 4 x 2  =  8
# 4 x 3  =  12
# 4 x 4  =  16
# 4 x 5  =  20
# 4 x 6  =  24
# 4 x 7  =  28
# 4 x 8  =  32
# 4 x 9  =  36
# 4 x 10  =  40
