# %%
#Questão1

n = int(input("Para iniciar digite um número maior que 0:"))
while n > 0:
  print(n)
  n = n - 1
# Out:
# Para iniciar digite um número maior que 0:7
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %%
n1=int(input("Digite um número:"))
n2=int(input("Digite um número:"))
d=0
while n1 <= n2:
  if n1 % 2 == 0:
    d = d + 1
    n1=n1+1
    print(d)
# Out:
# Digite um número:9
# Digite um número:7
