# %%
tabuada=int(input("Tabuada do número:"))

for count in range(10):
    print("%d * %d = %d" % (tabuada, count+1, tabuada*(count+1)))
# Out:
# Tabuada do número:3
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30
