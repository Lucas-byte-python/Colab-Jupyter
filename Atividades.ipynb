# %%
# 1º Faça um programa que pessa uma nota entre 0 e 10. Mostre uma mensagem caso o valor inválido e continue pedindo até que o usuário informe um valor válido.
n=0
while True:
  n = int(input(f'Digite uma nota para o lançamento.'))
  if (n>=0) and (n<=10):
    print(f'Nota digitada foi:', n)
    break
# Out:
# Digite uma nota para o lançamento.10
# Nota digitada foi: 10

# %%
def calc():
    def soma():
        n1=int(input('digite algo'))
        n2=int(input('digite outro'))
        print(n1+n2)
        while True:
            print()
            print('dcvdhvhv')
            print()
            escolha=int(input(':'))
            match escolha:
                case 1:
                    soma()
                    break
                case _:
                    print('asydegefjsvfhsvfjhfvev')
# Out:
#   File "<ipython-input-1-627cf8151f9b>", line 11
#     match escolha:
#           ^
# SyntaxError: invalid syntax

# %%
# 2° Faça um programa que leia um nome de usúario e a sua senha e não aceite a senha igual ao nome do usúario uma mensagem de erro e voltanado a perdir as informações.
nome= ''
senha=''
while True:
  nome=(input('Digite um nome:'))
  senha=(input('Digite uma senha:'))
  if (nome != senha):
    print('Cadastro válido.')
    break
  else:
    print('Cadastro inválido.')
    break
# Out:
# Digite um nome:s
# Digite uma senha:w
# Cadastro válido.

# %%
''' 3° Faça um programa que leia e valide as seguintes informações:
a. Nome: maior que 3 caracteres;
b. Idade: entre 0 e 150;
c. Salário: maior que 0;
d. Sexo: 'f' ou 'm';
e. Estado Civil: 's', 'c', 'v', 'd';'''
nome= ''
idade= 0
salario=0
sexo=['f', 'm']
EstadoCivil=['s','c','v','d']
fim= 'c'

while True:
  nome = input('Digite um nome:')
  if(len(nome)>3):
    print('Nome válido.')
  else:
    print('Nome inválido.')

  idade=int(input('Digite sua idade:'))
  if (idade >=0) and (idade<=150):
    print('Idade válida.')
  else:
    print('Idade inválida.')

  salario=float(input('Digite sua renda:'))
  if (salario == 0):
    print('Pobre:{salario:6.2f}')
  else:
    print('Rico')

  sexos= [({'s':'m', 'opcao':'masculino'}),
          ({'s': 'f','opcao': 'feminino'})]
  
  caractere= input('Digite seu sexo, f para feminino, m para masculino:')
  for sexo in sexos:
    if ((sexo['s']=='f') or (sexo['s']=='m')):
      print('Caractere correto.')
      break
    else:
      print('Você deve escolher f ou m.')

  fim= input('digite s ou S para sair:')
  if ((fim=='s')or (fim=='S')):
    print('Você optou por sair do sistema.')
    break
# Out:
# Nome válido.
# Idade válida.
# Rico
# Caractere correto.

# %%
'''4° Faça um programa que leia
