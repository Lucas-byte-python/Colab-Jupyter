# %%
lista=[2,3,4,5]

# %%
lista
# Out:
# [2, 3, 4, 5]

# %%
lista1 = [47, 565, 5.55, 54]

# %%
lista1
# Out:
# [47, 565, 5.55, 54]

# %%
lista2 = ['oi', [lista, lista1]]

# %%
lista2
# Out:
# ['oi', [[2, 3, 4, 5], [47, 565, 5.55, 54]]]
