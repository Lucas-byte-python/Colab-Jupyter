# %%
import pygame
pygame.init()
pygame.mixer.init()
pygame.mixer.music.load('/content/drive/MyDrive/Colab Notebooks/hungri (1).mp3')
pygame.mixer.music.play(loops=0, start=0.0)
pygame.event.wait()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-13-1c4e187e781e> in <module>
#       1 import pygame
#       2 pygame.init()
# ----> 3 pygame.mixer.init()
#       4 pygame.mixer.music.load('/content/drive/MyDrive/Colab Notebooks/hungri (1).mp3')
#       5 pygame.mixer.music.play(loops=0, start=0.0)
#
# error: ALSA: Couldn't open audio device: No such file or directory

# %%
from pygame import mixer

mixer.init() 

mixer.music.load("hungri.mp3")

mixer.music.play()

parar = input('Digite algo para parar...')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-35-c4b1e33b3b57> in <module>
#       1 from pygame import mixer
#       2
# ----> 3 mixer.init()
#       4
#       5 mixer.music.load("hungri.mp3")
#
# error: ALSA: Couldn't open audio device: No such file or directory

# %%
pip install mixer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 19.5 MB/s eta 0:00:00
# ...

# %%
pip install pygame
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 39.9 MB/s eta 0:00:00
# ...

# %%
pip install init
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for init: filename=init-0.1.0-py3-none-any.whl size=36345 sha256=ec4c72cb8b8a63734ff4850052665c7c0fa664e277b12ccbaf3a5ded58d0ee0c
#   Stored in directory: /root/.cache/pip/wheels/5a/98/cf/cef9797e2eef8b8193f04cb4309756f209837214b97e345b6a
# ...
#   Created wheel for terminal: filename=terminal-0.4.0-py3-none-any.whl size=13203 sha256=a2dbfb58c45f64bae3a7bdf6a4dae436069ff7bce3ffb8c631489cac8ec88a5d
#   Stored in directory: /root/.cache/pip/wheels/25/cf/3c/49dba1e4e6610ea5002c203aef022f50d9d345c19d08045d02
# Successfully built init terminal
# ...
