# %%
from math import inf
maior = -inf
menor = inf

soma = 0
contador = 0

while True:
  temperatura = float(input("Digite a temperatura em Kelvin. Negativa para parar:)) ")
  if temperatura < 0:
   contador = contador + 1
  soma += temperatura
  if temperatura < menor:
    menor = temperatura
  if temperatura > maior:
    maior = temperatura
  print(f"A menor temperatura foi {menor}K")
  print(f"A média das temperaturas foi {soma / contador:.3f}K")
    break
# Out:
#   File "<ipython-input-1-f748762ff7a6>", line 10
#     if temperatura < 0:
#                       ^
# SyntaxError: invalid syntax
