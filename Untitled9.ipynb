# %%
# Out:
#   File "<ipython-input-1-6eb16bad9cdf>", line 1
#     1Numero[1,2,3,4]
#      ^
# SyntaxError: invalid syntax

# %%
# Out:
#   File "<ipython-input-2-4aac079eef86>", line 1
#     print(1Numero)
#            ^
# SyntaxError: invalid syntax
